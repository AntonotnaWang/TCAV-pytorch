# %% [markdown]
# # TCAV implementation using pytorch
#
# #### reference: https://arxiv.org/abs/1711.11279

# %%
import numpy as np
import torch
from torchvision import models
from torch.autograd import Variable
import scipy.io
import json
import os
import random
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import copy
from PIL import Image, ImageFilter
from matplotlib import pyplot as plt

# %% [markdown]
# ### load image

# %%
# functions for image loading

pic_filepath = "imagenet_sample"

# modeloutput_id_wnid_class
def get_model_output_id_wnid_class_dict(jsonfilepath=pic_filepath+'/imagenet_label_index.json'):
    '''
    get the dict of model output ID, WNID and class name
    from the given json file
    format: {"Model Ouput ID": ["WNID", "Class"]}
    '''
    with open(jsonfilepath, 'r') as f:
        id_dict = json.load(f)
    
    return id_dict

# imagenet_id_wnid_class
def get_imagenet_id_wnid_class_dict(matfilepath=pic_filepath+'/ILSVRC2012_meta.mat'):
    '''
    get the dict of ImageNet ID, WNID and class name
    from the given mat file
    format: {"ImageNet ID": ["WNID", "class"]}, e.g. {..."233": ['n02106382', 'Bouvier_des_Flandres'], ...}
    '''
    meta=scipy.io.loadmat(matfilepath)['synsets']
    length=len(meta)
    id_dict={str(meta[0][0][0][0][0]):[meta[0][0][1][0], meta[0][0][2][0]]}
    for i in range(1, length):
        id_dict[str(meta[i][0][0][0][0])]=[meta[i][0][1][0], meta[i][0][2][0]]
        
    return id_dict

def map_model_id_to_imagenet_id(imagenet_id, modeloutput_id):
    '''
    return a dict mapping modeloutput id to imagenet id
    '''
    map_dict={}
    for imagenet_id_key in imagenet_id:
        for modeloutput_id_key in modeloutput_id:
            if modeloutput_id[modeloutput_id_key][0]==imagenet_id[imagenet_id_key][0]:
                map_dict[modeloutput_id_key]=imagenet_id_key
                break
    return map_dict

def map_imagenet_id_to_model_id(imagenet_id, modeloutput_id):
    '''
    return a dict mapping imagenet id to modeloutput id
    '''
    map_dict={}
    for imagenet_id_key in imagenet_id:
        for modeloutput_id_key in modeloutput_id:
            if modeloutput_id[modeloutput_id_key][0]==imagenet_id[imagenet_id_key][0]:
                map_dict[imagenet_id_key]=modeloutput_id_key
                break
    return map_dict

def get_img_names_and_labels_from_imagenet_sample(data_filepath=pic_filepath + "/imagenet_sample_5000"):
    img_files=os.listdir(data_filepath)
    img_files.sort()
    
    labels = []
    for idx, file in enumerate(img_files):
        labels.append(int(file.split("_")[0]))
    
    print("There are "+str(len(img_files))+" imgs, and "+str(len(np.unique(np.array(labels))))+" classes.")
    
    return img_files, labels

def load_img_from_imagenet_sample_by_index(index, imagenet_labels=None,
                                           data_filepath=pic_filepath + "/imagenet_sample_5000"):
    '''
    INPUT:
    index: (if data_filepath=pic_filepath + "/imagenet_sample_5000") 0~4999, which image file to load
    imagenet_labels: a dict, len=1000, {"ImageNet ID": ["WNID", "class"]}, e.g. {..."233": ['n02106382', 'Bouvier_des_Flandres'], ...}
    data_filepath:
    (name format of imgs: [ImageNet_ID]_[WNID]_[N].JPEG, N: 0~4, e.g. "141_n02104029_3.JPEG" means ImageNet ID: 141, WNID: n02104029,
    3nd pic of this class, and its class is 'kuvasz'.)
    
    OUTPUT:
    the img file
    '''
    img_files, labels = get_img_names_and_labels_from_imagenet_sample(data_filepath)
    
    load_img = Image.open(data_filepath+"/"+img_files[index]).convert('RGB')
    
    if imagenet_labels is not None:
        print("load img "+data_filepath+"/"+img_files[index]+\
              "\nImageNet ID: "+str(labels[index])+\
              "\nWNID and class: "+str(imagenet_labels[str(labels[index])]))
    else:
        print("load img "+data_filepath+"/"+img_files[index]+\
              "\nImageNet ID: "+str(labels[index]))
    
    return load_img, index, labels[index]

def load_img_from_imagenet_sample_by_class(imagenet_id, imagenet_labels=None,
                                           data_filepath=pic_filepath + "/imagenet_sample_5000"):
    '''
    INPUT:
    imagenet_id: 1~1000, indicating which class to load, we'll randomly choice one img in the class
    imagenet_labels: a dict, len=1000, {"ImageNet ID": ["WNID", "class"]}, e.g. {..."233": ['n02106382', 'Bouvier_des_Flandres'], ...}
    data_filepath:
    (name format of imgs: [ImageNet_ID]_[WNID]_[N].JPEG, N: 0~4, e.g. "141_n02104029_3.JPEG" means ImageNet ID: 141, WNID: n02104029,
    3nd pic of this class, and its class is 'kuvasz'.)
    
    OUTPUT:
    the img file
    '''
    img_files, labels = get_img_names_and_labels_from_imagenet_sample(data_filepath)
    
    idxs=np.where(np.array(labels)==imagenet_id)[0]
    chosen_idx=int(np.random.choice(idxs, 1))
    
    load_img = Image.open(data_filepath+"/"+img_files[chosen_idx]).convert('RGB')
    
    if imagenet_labels is not None:
        print("load img "+data_filepath+"/"+img_files[chosen_idx]+\
              "\nImageNet ID: "+str(labels[chosen_idx])+\
              "\nWNID and class: "+str(imagenet_labels[str(labels[chosen_idx])]))
    else:
        print("load img "+data_filepath+"/"+img_files[chosen_idx]+\
              "\nImageNet ID: "+str(labels[chosen_idx]))
    
    return load_img, chosen_idx, imagenet_id

# %%
# get the dict of ImageNet ID, WNID and class name
# format: {"ImageNet ID": ["WNID", "class"]}, e.g. {..."233": ['n02106382', 'Bouvier_des_Flandres'], ...}
imagenet_id_label=get_imagenet_id_wnid_class_dict()

# get the dict of model output ID, WNID and class name
# format: {"Model Ouput ID": ["WNID", "Class"]}
modeloutput_id_label=get_model_output_id_wnid_class_dict()

# get dict map model output ID to ImageNet ID
map_dict_model2imagenet=map_model_id_to_imagenet_id(imagenet_id_label, modeloutput_id_label)

# get ImageNet ID to dict map model output ID
map_dict_imagenet2model=map_imagenet_id_to_model_id(imagenet_id_label, modeloutput_id_label)

# %%
# show imagenet ids and labels
imagenet_id_label
# Out:
# {'1': ['n02119789', 'kit fox, Vulpes macrotis'],
#  '2': ['n02100735', 'English setter'],
#  '3': ['n02110185', 'Siberian husky'],
#  '4': ['n02096294', 'Australian terrier'],
#  '5': ['n02102040', 'English springer, English springer spaniel'],
#  '6': ['n02066245',
#   'grey whale, gray whale, devilfish, Eschrichtius gibbosus, Eschrichtius robustus'],
#  '7': ['n02509815',
#   'lesser panda, red panda, panda, bear cat, cat bear, Ailurus fulgens'],
#  '8': ['n02124075', 'Egyptian cat'],
#  '9': ['n02417914', 'ibex, Capra ibex'],
#  '10': ['n02123394', 'Persian cat'],
#  '11': ['n02125311',
#   'cougar, puma, catamount, mountain lion, painter, panther, Felis concolor'],
#  '12': ['n02423022', 'gazelle'],
#  '13': ['n02346627', 'porcupine, hedgehog'],
#  '14': ['n02077923', 'sea lion'],
#  '15': ['n02110063', 'malamute, malemute, Alaskan malamute'],
#  '16': ['n02447366', 'badger'],
#  '17': ['n02109047', 'Great Dane'],
#  '18': ['n02089867', 'Walker hound, Walker foxhound'],
#  '19': ['n02102177', 'Welsh springer spaniel'],
#  '20': ['n02091134', 'whippet'],
#  '21': ['n02092002', 'Scottish deerhound, deerhound'],
#  '22': ['n02071294',
#   'killer whale, killer, orca, grampus, sea wolf, Orcinus orca'],
#  '23': ['n02442845', 'mink'],
#  '24': ['n02504458', 'African elephant, Loxodonta africana'],
#  '25': ['n02092339', 'Weimaraner'],
#  '26': ['n02098105', 'soft-coated wheaten terrier'],
#  '27': ['n02096437', 'Dandie Dinmont, Dandie Dinmont terrier'],
#  '28': ['n02114712', 'red wolf, maned wolf, Canis rufus, Canis niger'],
#  '29': ['n02105641', 'Old English sheepdog, bobtail'],
#  '30': ['n02128925', 'jaguar, panther, Panthera onca, Felis onca'],
#  '31': ['n02091635', 'otterhound, otter hound'],
#  '32': ['n02088466', 'bloodhound, sleuthhound'],
#  '33': ['n02096051', 'Airedale, Airedale terrier'],
#  '34': ['n02117135', 'hyena, hyaena'],
#  '35': ['n02138441', 'meerkat, mierkat'],
#  '36': ['n02097130', 'giant schnauzer'],
#  '37': ['n02493509', 'titi, titi monkey'],
#  '38': ['n02457408', 'three-toed sloth, ai, Bradypus tridactylus'],
#  '39': ['n02389026', 'sorrel'],
#  '40': ['n02443484', 'black-footed ferret, ferret, Mustela nigripes'],
#  '41': ['n02110341', 'dalmatian, coach dog, carriage dog'],
#  '42': ['n02089078', 'black-and-tan coonhound'],
#  '43': ['n02086910', 'papillon'],
#  '44': ['n02445715', 'skunk, polecat, wood pussy'],
#  '45': ['n02093256', 'Staffordshire bullterrier, Staffordshire bull terrier'],
#  '46': ['n02113978', 'Mexican hairless'],
#  '47': ['n02106382', 'Bouvier des Flandres, Bouviers des Flandres'],
#  '48': ['n02441942', 'weasel'],
#  '49': ['n02113712', 'miniature poodle'],
#  '50': ['n02113186', 'Cardigan, Cardigan Welsh corgi'],
#  '51': ['n02105162', 'malinois'],
#  '52': ['n02415577',
#   'bighorn, bighorn sheep, cimarron, Rocky Mountain bighorn, Rocky Mountain sheep, Ovis canadensis'],
#  '53': ['n02356798', 'fox squirrel, eastern fox squirrel, Sciurus niger'],
#  '54': ['n02488702', 'colobus, colobus monkey'],
#  '55': ['n02123159', 'tiger cat'],
#  '56': ['n02098413', 'Lhasa, Lhasa apso'],
#  '57': ['n02422699', 'impala, Aepyceros melampus'],
#  '58': ['n02114855', 'coyote, prairie wolf, brush wolf, Canis latrans'],
#  '59': ['n02094433', 'Yorkshire terrier'],
#  '60': ['n02111277', 'Newfoundland, Newfoundland dog'],
#  '61': ['n02132136', 'brown bear, bruin, Ursus arctos'],
#  '62': ['n02119022', 'red fox, Vulpes vulpes'],
#  '63': ['n02091467', 'Norwegian elkhound, elkhound'],
#  '64': ['n02106550', 'Rottweiler'],
#  '65': ['n02422106', 'hartebeest'],
#  '66': ['n02091831', 'Saluki, gazelle hound'],
#  '67': ['n02120505', 'grey fox, gray fox, Urocyon cinereoargenteus'],
#  '68': ['n02104365', 'schipperke'],
#  '69': ['n02086079', 'Pekinese, Pekingese, Peke'],
#  '70': ['n02112706', 'Brabancon griffon'],
#  '71': ['n02098286', 'West Highland white terrier'],
#  '72': ['n02095889', 'Sealyham terrier, Sealyham'],
#  '73': ['n02484975', 'guenon, guenon monkey'],
#  '74': ['n02137549', 'mongoose'],
#  '75': ['n02500267', 'indri, indris, Indri indri, Indri brevicaudatus'],
#  '76': ['n02129604', 'tiger, Panthera tigris'],
#  '77': ['n02090721', 'Irish wolfhound'],
#  '78': ['n02396427', 'wild boar, boar, Sus scrofa'],
#  '79': ['n02108000', 'EntleBucher'],
#  '80': ['n02391049', 'zebra'],
#  '81': ['n02412080', 'ram, tup'],
#  '82': ['n02108915', 'French bulldog'],
#  '83': ['n02480495', 'orangutan, orang, orangutang, Pongo pygmaeus'],
#  '84': ['n02110806', 'basenji'],
#  '85': ['n02128385', 'leopard, Panthera pardus'],
#  '86': ['n02107683', 'Bernese mountain dog'],
#  '87': ['n02085936', 'Maltese dog, Maltese terrier, Maltese'],
#  '88': ['n02094114', 'Norfolk terrier'],
#  '89': ['n02087046', 'toy terrier'],
#  '90': ['n02100583', 'vizsla, Hungarian pointer'],
#  '91': ['n02096177', 'cairn, cairn terrier'],
#  '92': ['n02494079', 'squirrel monkey, Saimiri sciureus'],
#  '93': ['n02105056', 'groenendael'],
#  '94': ['n02101556', 'clumber, clumber spaniel'],
#  '95': ['n02123597', 'Siamese cat, Siamese'],
#  '96': ['n02481823', 'chimpanzee, chimp, Pan troglodytes'],
#  '97': ['n02105505', 'komondor'],
#  '98': ['n02088094', 'Afghan hound, Afghan'],
#  '99': ['n02085782', 'Japanese spaniel'],
#  '100': ['n02489166', 'proboscis monkey, Nasalis larvatus'],
#  '101': ['n02364673', 'guinea pig, Cavia cobaya'],
#  '102': ['n02114548', 'white wolf, Arctic wolf, Canis lupus tundrarum'],
#  '103': ['n02134084',
#   'ice bear, polar bear, Ursus Maritimus, Thalarctos maritimus'],
#  '104': ['n02480855', 'gorilla, Gorilla gorilla'],
#  '105': ['n02090622', 'borzoi, Russian wolfhound'],
#  '106': ['n02113624', 'toy poodle'],
#  '107': ['n02093859', 'Kerry blue terrier'],
#  '108': ['n02403003', 'ox'],
#  '109': ['n02097298', 'Scotch terrier, Scottish terrier, Scottie'],
#  '110': ['n02108551', 'Tibetan mastiff'],
#  '111': ['n02493793', 'spider monkey, Ateles geoffroyi'],
#  '112': ['n02107142', 'Doberman, Doberman pinscher'],
#  '113': ['n02096585', 'Boston bull, Boston terrier'],
#  '114': ['n02107574', 'Greater Swiss Mountain dog'],
#  '115': ['n02107908', 'Appenzeller'],
#  '116': ['n02086240', 'Shih-Tzu'],
#  '117': ['n02102973', 'Irish water spaniel'],
#  '118': ['n02112018', 'Pomeranian'],
#  '119': ['n02093647', 'Bedlington terrier'],
#  '120': ['n02397096', 'warthog'],
#  '121': ['n02437312', 'Arabian camel, dromedary, Camelus dromedarius'],
#  '122': ['n02483708',
#   'siamang, Hylobates syndactylus, Symphalangus syndactylus'],
#  '123': ['n02097047', 'miniature schnauzer'],
#  '124': ['n02106030', 'collie'],
#  '125': ['n02099601', 'golden retriever'],
#  '126': ['n02093991', 'Irish terrier'],
#  '127': ['n02110627', 'affenpinscher, monkey pinscher, monkey dog'],
#  '128': ['n02106166', 'Border collie'],
#  '129': ['n02326432', 'hare'],
#  '130': ['n02108089', 'boxer'],
#  '131': ['n02097658', 'silky terrier, Sydney silky'],
#  '132': ['n02088364', 'beagle'],
#  '133': ['n02111129', 'Leonberg'],
#  '134': ['n02100236', 'German short-haired pointer'],
#  '135': ['n02486261', 'patas, hussar monkey, Erythrocebus patas'],
#  '136': ['n02115913', 'dhole, Cuon alpinus'],
#  '137': ['n02486410', 'baboon'],
#  '138': ['n02487347', 'macaque'],
#  '139': ['n02099849', 'Chesapeake Bay retriever'],
#  '140': ['n02108422', 'bull mastiff'],
#  '141': ['n02104029', 'kuvasz'],
#  '142': ['n02492035', 'capuchin, ringtail, Cebus capucinus'],
#  '143': ['n02110958', 'pug, pug-dog'],
#  '144': ['n02099429', 'curly-coated retriever'],
#  '145': ['n02094258', 'Norwich terrier'],
#  '146': ['n02099267', 'flat-coated retriever'],
#  '147': ['n02395406', 'hog, pig, grunter, squealer, Sus scrofa'],
#  '148': ['n02112350', 'keeshond'],
#  '149': ['n02109961', 'Eskimo dog, husky'],
#  '150': ['n02101388', 'Brittany spaniel'],
#  '151': ['n02113799', 'standard poodle'],
#  '152': ['n02095570', 'Lakeland terrier'],
#  '153': ['n02128757', 'snow leopard, ounce, Panthera uncia'],
#  '154': ['n02101006', 'Gordon setter'],
#  '155': ['n02115641', 'dingo, warrigal, warragal, Canis dingo'],
#  '156': ['n02097209', 'standard schnauzer'],
#  '157': ['n02342885', 'hamster'],
#  '158': ['n02097474', 'Tibetan terrier, chrysanthemum dog'],
#  '159': ['n02120079', 'Arctic fox, white fox, Alopex lagopus'],
#  '160': ['n02095314', 'wire-haired fox terrier'],
#  '161': ['n02088238', 'basset, basset hound'],
#  '162': ['n02408429',
#   'water buffalo, water ox, Asiatic buffalo, Bubalus bubalis'],
#  '163': ['n02133161',
#   'American black bear, black bear, Ursus americanus, Euarctos americanus'],
#  '164': ['n02328150', 'Angora, Angora rabbit'],
#  '165': ['n02410509', 'bison'],
#  '166': ['n02492660', 'howler monkey, howler'],
#  '167': ['n02398521',
#   'hippopotamus, hippo, river horse, Hippopotamus amphibius'],
#  '168': ['n02112137', 'chow, chow chow'],
#  '169': ['n02510455',
#   'giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca'],
#  '170': ['n02093428',
#   'American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier'],
#  '171': ['n02105855', 'Shetland sheepdog, Shetland sheep dog, Shetland'],
#  '172': ['n02111500', 'Great Pyrenees'],
#  '173': ['n02085620', 'Chihuahua'],
#  '174': ['n02123045', 'tabby, tabby cat'],
#  '175': ['n02490219', 'marmoset'],
#  '176': ['n02099712', 'Labrador retriever'],
#  '177': ['n02109525', 'Saint Bernard, St Bernard'],
#  '178': ['n02454379', 'armadillo'],
#  '179': ['n02111889', 'Samoyed, Samoyede'],
#  '180': ['n02088632', 'bluetick'],
#  '181': ['n02090379', 'redbone'],
#  '182': ['n02443114', 'polecat, fitch, foulmart, foumart, Mustela putorius'],
#  '183': ['n02361337', 'marmot'],
#  '184': ['n02105412', 'kelpie'],
#  '185': ['n02483362', 'gibbon, Hylobates lar'],
#  '186': ['n02437616', 'llama'],
#  '187': ['n02107312', 'miniature pinscher'],
#  '188': ['n02325366', 'wood rabbit, cottontail, cottontail rabbit'],
#  '189': ['n02091032', 'Italian greyhound'],
#  '190': ['n02129165', 'lion, king of beasts, Panthera leo'],
#  '191': ['n02102318', 'cocker spaniel, English cocker spaniel, cocker'],
#  '192': ['n02100877', 'Irish setter, red setter'],
#  '193': ['n02074367', 'dugong, Dugong dugon'],
#  '194': ['n02504013', 'Indian elephant, Elephas maximus'],
#  '195': ['n02363005', 'beaver'],
#  '196': ['n02102480', 'Sussex spaniel'],
#  '197': ['n02113023', 'Pembroke, Pembroke Welsh corgi'],
#  '198': ['n02086646', 'Blenheim spaniel'],
#  '199': ['n02497673', 'Madagascar cat, ring-tailed lemur, Lemur catta'],
#  '200': ['n02087394', 'Rhodesian ridgeback'],
#  '201': ['n02127052', 'lynx, catamount'],
#  '202': ['n02116738',
#   'African hunting dog, hyena dog, Cape hunting dog, Lycaon pictus'],
#  '203': ['n02488291', 'langur'],
#  '204': ['n02091244', 'Ibizan hound, Ibizan Podenco'],
#  '205': ['n02114367', 'timber wolf, grey wolf, gray wolf, Canis lupus'],
#  '206': ['n02130308', 'cheetah, chetah, Acinonyx jubatus'],
#  '207': ['n02089973', 'English foxhound'],
#  '208': ['n02105251', 'briard'],
#  '209': ['n02134418', 'sloth bear, Melursus ursinus, Ursus ursinus'],
#  '210': ['n02093754', 'Border terrier'],
#  '211': ['n02106662',
#   'German shepherd, German shepherd dog, German police dog, alsatian'],
#  '212': ['n02444819', 'otter'],
#  '213': ['n01882714',
#   'koala, koala bear, kangaroo bear, native bear, Phascolarctos cinereus'],
#  '214': ['n01871265', 'tusker'],
#  '215': ['n01872401', 'echidna, spiny anteater, anteater'],
#  '216': ['n01877812', 'wallaby, brush kangaroo'],
#  '217': ['n01873310',
#   'platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus'],
#  '218': ['n01883070', 'wombat'],
#  '219': ['n04086273', 'revolver, six-gun, six-shooter'],
#  '220': ['n04507155', 'umbrella'],
#  '221': ['n04147183', 'schooner'],
#  '222': ['n04254680', 'soccer ball'],
#  '223': ['n02672831', 'accordion, piano accordion, squeeze box'],
#  '224': ['n02219486', 'ant, emmet, pismire'],
#  '225': ['n02317335', 'starfish, sea star'],
#  '226': ['n01968897', 'chambered nautilus, pearly nautilus, nautilus'],
#  '227': ['n03452741', 'grand piano, grand'],
#  '228': ['n03642806', 'laptop, laptop computer'],
#  '229': ['n07745940', 'strawberry'],
#  '230': ['n02690373', 'airliner'],
#  '231': ['n04552348', 'warplane, military plane'],
#  '232': ['n02692877', 'airship, dirigible'],
#  '233': ['n02782093', 'balloon'],
#  '234': ['n04266014', 'space shuttle'],
#  '235': ['n03344393', 'fireboat'],
#  '236': ['n03447447', 'gondola'],
#  '237': ['n04273569', 'speedboat'],
#  '238': ['n03662601', 'lifeboat'],
#  '239': ['n02951358', 'canoe'],
#  '240': ['n04612504', 'yawl'],
#  '241': ['n02981792', 'catamaran'],
#  '242': ['n04483307', 'trimaran'],
#  '243': ['n03095699', 'container ship, containership, container vessel'],
#  '244': ['n03673027', 'liner, ocean liner'],
#  '245': ['n03947888', 'pirate, pirate ship'],
#  '246': ['n02687172',
#   'aircraft carrier, carrier, flattop, attack aircraft carrier'],
#  '247': ['n04347754', 'submarine, pigboat, sub, U-boat'],
#  '248': ['n04606251', 'wreck'],
#  '249': ['n03478589', 'half track'],
#  '250': ['n04389033',
#   'tank, army tank, armored combat vehicle, armoured combat vehicle'],
#  '251': ['n03773504', 'missile'],
#  '252': ['n02860847', 'bobsled, bobsleigh, bob'],
#  '253': ['n03218198', 'dogsled, dog sled, dog sleigh'],
#  '254': ['n02835271', 'bicycle-built-for-two, tandem bicycle, tandem'],
#  '255': ['n03792782', 'mountain bike, all-terrain bike, off-roader'],
#  '256': ['n03393912', 'freight car'],
#  '257': ['n03895866', 'passenger car, coach, carriage'],
#  '258': ['n02797295', 'barrow, garden cart, lawn cart, wheelbarrow'],
#  '259': ['n04204347', 'shopping cart'],
#  '260': ['n03791053', 'motor scooter, scooter'],
#  '261': ['n03384352', 'forklift'],
#  '262': ['n03272562', 'electric locomotive'],
#  '263': ['n04310018', 'steam locomotive'],
#  '264': ['n02704792', 'amphibian, amphibious vehicle'],
#  '265': ['n02701002', 'ambulance'],
#  '266': ['n02814533',
#   'beach wagon, station wagon, wagon, estate car, beach waggon, station waggon, waggon'],
#  '267': ['n02930766', 'cab, hack, taxi, taxicab'],
#  '268': ['n03100240', 'convertible'],
#  '269': ['n03594945', 'jeep, landrover'],
#  '270': ['n03670208', 'limousine, limo'],
#  '271': ['n03770679', 'minivan'],
#  '272': ['n03777568', 'Model T'],
#  '273': ['n04037443', 'racer, race car, racing car'],
#  '274': ['n04285008', 'sports car, sport car'],
#  '275': ['n03444034', 'go-kart'],
#  '276': ['n03445924', 'golfcart, golf cart'],
#  '277': ['n03785016', 'moped'],
#  '278': ['n04252225', 'snowplow, snowplough'],
#  '279': ['n03345487', 'fire engine, fire truck'],
#  '280': ['n03417042', 'garbage truck, dustcart'],
#  '281': ['n03930630', 'pickup, pickup truck'],
#  '282': ['n04461696', 'tow truck, tow car, wrecker'],
#  '283': ['n04467665',
#   'trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi'],
#  '284': ['n03796401', 'moving van'],
#  '285': ['n03977966',
#   'police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria'],
#  '286': ['n04065272', 'recreational vehicle, RV, R.V.'],
#  '287': ['n04335435', 'streetcar, tram, tramcar, trolley, trolley car'],
#  '288': ['n04252077', 'snowmobile'],
#  '289': ['n04465501', 'tractor'],
#  '290': ['n03776460', 'mobile home, manufactured home'],
#  '291': ['n04482393', 'tricycle, trike, velocipede'],
#  '292': ['n04509417', 'unicycle, monocycle'],
#  '293': ['n03538406', 'horse cart, horse-cart'],
#  '294': ['n03599486', 'jinrikisha, ricksha, rickshaw'],
#  '295': ['n03868242', 'oxcart'],
#  '296': ['n02804414', 'bassinet'],
#  '297': ['n03125729', 'cradle'],
#  '298': ['n03131574', 'crib, cot'],
#  '299': ['n03388549', 'four-poster'],
#  '300': ['n02870880', 'bookcase'],
#  '301': ['n03018349', 'china cabinet, china closet'],
#  '302': ['n03742115', 'medicine chest, medicine cabinet'],
#  '303': ['n03016953', 'chiffonier, commode'],
#  '304': ['n04380533', 'table lamp'],
#  '305': ['n03337140', 'file, file cabinet, filing cabinet'],
#  '306': ['n03891251', 'park bench'],
#  '307': ['n02791124', 'barber chair'],
#  '308': ['n04429376', 'throne'],
#  '309': ['n03376595', 'folding chair'],
#  '310': ['n04099969', 'rocking chair, rocker'],
#  '311': ['n04344873', 'studio couch, day bed'],
#  '312': ['n04447861', 'toilet seat'],
#  '313': ['n03179701', 'desk'],
#  '314': ['n03982430', 'pool table, billiard table, snooker table'],
#  '315': ['n03201208', 'dining table, board'],
#  '316': ['n03290653', 'entertainment center'],
#  '317': ['n04550184', 'wardrobe, closet, press'],
#  '318': ['n07742313', 'Granny Smith'],
#  '319': ['n07747607', 'orange'],
#  '320': ['n07749582', 'lemon'],
#  '321': ['n07753113', 'fig'],
#  '322': ['n07753275', 'pineapple, ananas'],
#  '323': ['n07753592', 'banana'],
#  '324': ['n07754684', 'jackfruit, jak, jack'],
#  '325': ['n07760859', 'custard apple'],
#  '326': ['n07768694', 'pomegranate'],
#  '327': ['n12267677', 'acorn'],
#  '328': ['n12620546', 'hip, rose hip, rosehip'],
#  '329': ['n13133613', 'ear, spike, capitulum'],
#  '330': ['n11879895', 'rapeseed'],
#  '331': ['n12144580', 'corn'],
#  '332': ['n12768682', 'buckeye, horse chestnut, conker'],
#  '333': ['n03854065', 'organ, pipe organ'],
#  '334': ['n04515003', 'upright, upright piano'],
#  '335': ['n03017168', 'chime, bell, gong'],
#  '336': ['n03249569', 'drum, membranophone, tympan'],
#  '337': ['n03447721', 'gong, tam-tam'],
#  '338': ['n03720891', 'maraca'],
#  '339': ['n03721384', 'marimba, xylophone'],
#  '340': ['n04311174', 'steel drum'],
#  '341': ['n02787622', 'banjo'],
#  '342': ['n02992211', 'cello, violoncello'],
#  '343': ['n04536866', 'violin, fiddle'],
#  '344': ['n03495258', 'harp'],
#  '345': ['n02676566', 'acoustic guitar'],
#  '346': ['n03272010', 'electric guitar'],
#  '347': ['n03110669', 'cornet, horn, trumpet, trump'],
#  '348': ['n03394916', 'French horn, horn'],
#  '349': ['n04487394', 'trombone'],
#  '350': ['n03494278', 'harmonica, mouth organ, harp, mouth harp'],
#  '351': ['n03840681', 'ocarina, sweet potato'],
#  '352': ['n03884397', 'panpipe, pandean pipe, syrinx'],
#  '353': ['n02804610', 'bassoon'],
#  '354': ['n03838899', 'oboe, hautboy, hautbois'],
#  '355': ['n04141076', 'sax, saxophone'],
#  '356': ['n03372029', 'flute, transverse flute'],
#  '357': ['n11939491', 'daisy'],
#  '358': ['n12057211',
#   "yellow lady's slipper, yellow lady-slipper, Cypripedium calceolus, Cypripedium parviflorum"],
#  '359': ['n09246464', 'cliff, drop, drop-off'],
#  '360': ['n09468604', 'valley, vale'],
#  '361': ['n09193705', 'alp'],
#  '362': ['n09472597', 'volcano'],
#  '363': ['n09399592', 'promontory, headland, head, foreland'],
#  '364': ['n09421951', 'sandbar, sand bar'],
#  '365': ['n09256479', 'coral reef'],
#  '366': ['n09332890', 'lakeside, lakeshore'],
#  '367': ['n09428293', 'seashore, coast, seacoast, sea-coast'],
#  '368': ['n09288635', 'geyser'],
#  '369': ['n03498962', 'hatchet'],
#  '370': ['n03041632', 'cleaver, meat cleaver, chopper'],
#  '371': ['n03658185', 'letter opener, paper knife, paperknife'],
#  '372': ['n03954731', "plane, carpenter's plane, woodworking plane"],
#  '373': ['n03995372', 'power drill'],
#  '374': ['n03649909', 'lawn mower, mower'],
#  '375': ['n03481172', 'hammer'],
#  '376': ['n03109150', 'corkscrew, bottle screw'],
#  '377': ['n02951585', 'can opener, tin opener'],
#  '378': ['n03970156', "plunger, plumber's helper"],
#  '379': ['n04154565', 'screwdriver'],
#  '380': ['n04208210', 'shovel'],
#  '381': ['n03967562', 'plow, plough'],
#  '382': ['n03000684', 'chain saw, chainsaw'],
#  '383': ['n01514668', 'cock'],
#  '384': ['n01514859', 'hen'],
#  '385': ['n01518878', 'ostrich, Struthio camelus'],
#  '386': ['n01530575', 'brambling, Fringilla montifringilla'],
#  '387': ['n01531178', 'goldfinch, Carduelis carduelis'],
#  '388': ['n01532829', 'house finch, linnet, Carpodacus mexicanus'],
#  '389': ['n01534433', 'junco, snowbird'],
#  '390': ['n01537544',
#   'indigo bunting, indigo finch, indigo bird, Passerina cyanea'],
#  '391': ['n01558993', 'robin, American robin, Turdus migratorius'],
#  '392': ['n01560419', 'bulbul'],
#  '393': ['n01580077', 'jay'],
#  '394': ['n01582220', 'magpie'],
#  '395': ['n01592084', 'chickadee'],
#  '396': ['n01601694', 'water ouzel, dipper'],
#  '397': ['n01608432', 'kite'],
#  '398': ['n01614925', 'bald eagle, American eagle, Haliaeetus leucocephalus'],
#  '399': ['n01616318', 'vulture'],
#  '400': ['n01622779', 'great grey owl, great gray owl, Strix nebulosa'],
#  '401': ['n01795545', 'black grouse'],
#  '402': ['n01796340', 'ptarmigan'],
#  '403': ['n01797886', 'ruffed grouse, partridge, Bonasa umbellus'],
#  '404': ['n01798484', 'prairie chicken, prairie grouse, prairie fowl'],
#  '405': ['n01806143', 'peacock'],
#  '406': ['n01806567', 'quail'],
#  '407': ['n01807496', 'partridge'],
#  '408': ['n01817953', 'African grey, African gray, Psittacus erithacus'],
#  '409': ['n01818515', 'macaw'],
#  '410': ['n01819313',
#   'sulphur-crested cockatoo, Kakatoe galerita, Cacatua galerita'],
#  '411': ['n01820546', 'lorikeet'],
#  '412': ['n01824575', 'coucal'],
#  '413': ['n01828970', 'bee eater'],
#  '414': ['n01829413', 'hornbill'],
#  '415': ['n01833805', 'hummingbird'],
#  '416': ['n01843065', 'jacamar'],
#  '417': ['n01843383', 'toucan'],
#  '418': ['n01847000', 'drake'],
#  '419': ['n01855032', 'red-breasted merganser, Mergus serrator'],
#  '420': ['n01855672', 'goose'],
#  '421': ['n01860187', 'black swan, Cygnus atratus'],
#  '422': ['n02002556', 'white stork, Ciconia ciconia'],
#  '423': ['n02002724', 'black stork, Ciconia nigra'],
#  '424': ['n02006656', 'spoonbill'],
#  '425': ['n02007558', 'flamingo'],
#  '426': ['n02009912', 'American egret, great white heron, Egretta albus'],
#  '427': ['n02009229', 'little blue heron, Egretta caerulea'],
#  '428': ['n02011460', 'bittern'],
#  '429': ['n02012849', 'crane'],
#  '430': ['n02013706', 'limpkin, Aramus pictus'],
#  '431': ['n02018207',
#   'American coot, marsh hen, mud hen, water hen, Fulica americana'],
#  '432': ['n02018795', 'bustard'],
#  '433': ['n02025239', 'ruddy turnstone, Arenaria interpres'],
#  '434': ['n02027492', 'red-backed sandpiper, dunlin, Erolia alpina'],
#  '435': ['n02028035', 'redshank, Tringa totanus'],
#  '436': ['n02033041', 'dowitcher'],
#  '437': ['n02037110', 'oystercatcher, oyster catcher'],
#  '438': ['n02017213', 'European gallinule, Porphyrio porphyrio'],
#  '439': ['n02051845', 'pelican'],
#  '440': ['n02056570', 'king penguin, Aptenodytes patagonica'],
#  '441': ['n02058221', 'albatross, mollymawk'],
#  '442': ['n01484850',
#   'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias'],
#  '443': ['n01491361', 'tiger shark, Galeocerdo cuvieri'],
#  '444': ['n01494475', 'hammerhead, hammerhead shark'],
#  '445': ['n01496331', 'electric ray, crampfish, numbfish, torpedo'],
#  '446': ['n01498041', 'stingray'],
#  '447': ['n02514041', 'barracouta, snoek'],
#  '448': ['n02536864',
#   'coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch'],
#  '449': ['n01440764', 'tench, Tinca tinca'],
#  '450': ['n01443537', 'goldfish, Carassius auratus'],
#  '451': ['n02526121', 'eel'],
#  '452': ['n02606052', 'rock beauty, Holocanthus tricolor'],
#  '453': ['n02607072', 'anemone fish'],
#  '454': ['n02643566', 'lionfish'],
#  '455': ['n02655020', 'puffer, pufferfish, blowfish, globefish'],
#  '456': ['n02640242', 'sturgeon'],
#  '457': ['n02641379', 'gar, garfish, garpike, billfish, Lepisosteus osseus'],
#  '458': ['n01664065', 'loggerhead, loggerhead turtle, Caretta caretta'],
#  '459': ['n01665541',
#   'leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea'],
#  '460': ['n01667114', 'mud turtle'],
#  '461': ['n01667778', 'terrapin'],
#  '462': ['n01669191', 'box turtle, box tortoise'],
#  '463': ['n01675722', 'banded gecko'],
#  '464': ['n01677366', 'common iguana, iguana, Iguana iguana'],
#  '465': ['n01682714', 'American chameleon, anole, Anolis carolinensis'],
#  '466': ['n01685808', 'whiptail, whiptail lizard'],
#  '467': ['n01687978', 'agama'],
#  '468': ['n01688243', 'frilled lizard, Chlamydosaurus kingi'],
#  '469': ['n01689811', 'alligator lizard'],
#  '470': ['n01692333', 'Gila monster, Heloderma suspectum'],
#  '471': ['n01693334', 'green lizard, Lacerta viridis'],
#  '472': ['n01694178', 'African chameleon, Chamaeleo chamaeleon'],
#  '473': ['n01695060',
#   'Komodo dragon, Komodo lizard, dragon lizard, giant lizard, Varanus komodoensis'],
#  '474': ['n01704323', 'triceratops'],
#  '475': ['n01697457',
#   'African crocodile, Nile crocodile, Crocodylus niloticus'],
#  '476': ['n01698640', 'American alligator, Alligator mississipiensis'],
#  '477': ['n01728572', 'thunder snake, worm snake, Carphophis amoenus'],
#  '478': ['n01728920', 'ringneck snake, ring-necked snake, ring snake'],
#  '479': ['n01729322', 'hognose snake, puff adder, sand viper'],
#  '480': ['n01729977', 'green snake, grass snake'],
#  '481': ['n01734418', 'king snake, kingsnake'],
#  '482': ['n01735189', 'garter snake, grass snake'],
#  '483': ['n01737021', 'water snake'],
#  '484': ['n01739381', 'vine snake'],
#  '485': ['n01740131', 'night snake, Hypsiglena torquata'],
#  '486': ['n01742172', 'boa constrictor, Constrictor constrictor'],
#  '487': ['n01744401', 'rock python, rock snake, Python sebae'],
#  '488': ['n01748264', 'Indian cobra, Naja naja'],
#  '489': ['n01749939', 'green mamba'],
#  '490': ['n01751748', 'sea snake'],
#  '491': ['n01753488',
#   'horned viper, cerastes, sand viper, horned asp, Cerastes cornutus'],
#  '492': ['n01755581',
#   'diamondback, diamondback rattlesnake, Crotalus adamanteus'],
#  '493': ['n01756291', 'sidewinder, horned rattlesnake, Crotalus cerastes'],
#  '494': ['n01629819', 'European fire salamander, Salamandra salamandra'],
#  '495': ['n01630670', 'common newt, Triturus vulgaris'],
#  '496': ['n01631663', 'eft'],
#  '497': ['n01632458', 'spotted salamander, Ambystoma maculatum'],
#  '498': ['n01632777', 'axolotl, mud puppy, Ambystoma mexicanum'],
#  '499': ['n01641577', 'bullfrog, Rana catesbeiana'],
#  '500': ['n01644373', 'tree frog, tree-frog'],
#  '501': ['n01644900',
#   'tailed frog, bell toad, ribbed toad, tailed toad, Ascaphus trui'],
#  '502': ['n04579432', 'whistle'],
#  '503': ['n04592741', 'wing'],
#  '504': ['n03876231', 'paintbrush'],
#  '505': ['n03483316',
#   'hand blower, blow dryer, blow drier, hair dryer, hair drier'],
#  '506': ['n03868863', 'oxygen mask'],
#  '507': ['n04251144', 'snorkel'],
#  '508': ['n03691459',
#   'loudspeaker, speaker, speaker unit, loudspeaker system, speaker system'],
#  '509': ['n03759954', 'microphone, mike'],
#  '510': ['n04152593', 'screen, CRT screen'],
#  '511': ['n03793489', 'mouse, computer mouse'],
#  '512': ['n03271574', 'electric fan, blower'],
#  '513': ['n03843555', 'oil filter'],
#  '514': ['n04332243', 'strainer'],
#  '515': ['n04265275', 'space heater'],
#  '516': ['n04330267', 'stove'],
#  '517': ['n03467068', 'guillotine'],
#  '518': ['n02794156', 'barometer'],
#  '519': ['n04118776', 'rule, ruler'],
#  '520': ['n03841143', 'odometer, hodometer, mileometer, milometer'],
#  '521': ['n04141975', 'scale, weighing machine'],
#  '522': ['n02708093', 'analog clock'],
#  '523': ['n03196217', 'digital clock'],
#  '524': ['n04548280', 'wall clock'],
#  '525': ['n03544143', 'hourglass'],
#  '526': ['n04355338', 'sundial'],
#  '527': ['n03891332', 'parking meter'],
#  '528': ['n04328186', 'stopwatch, stop watch'],
#  '529': ['n03197337', 'digital watch'],
#  '530': ['n04317175', 'stethoscope'],
#  '531': ['n04376876', 'syringe'],
#  '532': ['n03706229', 'magnetic compass'],
#  '533': ['n02841315', 'binoculars, field glasses, opera glasses'],
#  '534': ['n04009552', 'projector'],
#  '535': ['n04356056', 'sunglasses, dark glasses, shades'],
#  '536': ['n03692522', "loupe, jeweler's loupe"],
#  '537': ['n04044716', 'radio telescope, radio reflector'],
#  '538': ['n02879718', 'bow'],
#  '539': ['n02950826', 'cannon'],
#  '540': ['n02749479', 'assault rifle, assault gun'],
#  '541': ['n04090263', 'rifle'],
#  '542': ['n04008634', 'projectile, missile'],
#  '543': ['n03085013', 'computer keyboard, keypad'],
#  '544': ['n04505470', 'typewriter keyboard'],
#  '545': ['n03126707', 'crane'],
#  '546': ['n03666591', 'lighter, light, igniter, ignitor'],
#  '547': ['n02666196', 'abacus'],
#  '548': ['n02977058',
#   'cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM'],
#  '549': ['n04238763', 'slide rule, slipstick'],
#  '550': ['n03180011', 'desktop computer'],
#  '551': ['n03485407', 'hand-held computer, hand-held microcomputer'],
#  '552': ['n03832673', 'notebook, notebook computer'],
#  '553': ['n06359193', 'web site, website, internet site, site'],
#  '554': ['n03496892', 'harvester, reaper'],
#  '555': ['n04428191', 'thresher, thrasher, threshing machine'],
#  '556': ['n04004767', 'printer'],
#  '557': ['n04243546', 'slot, one-armed bandit'],
#  '558': ['n04525305', 'vending machine'],
#  '559': ['n04179913', 'sewing machine'],
#  '560': ['n03602883', 'joystick'],
#  '561': ['n04372370', 'switch, electric switch, electrical switch'],
#  '562': ['n03532672', 'hook, claw'],
#  '563': ['n02974003', 'car wheel'],
#  '564': ['n03874293', 'paddlewheel, paddle wheel'],
#  '565': ['n03944341', 'pinwheel'],
#  '566': ['n03992509', "potter's wheel"],
#  '567': ['n03425413',
#   'gas pump, gasoline pump, petrol pump, island dispenser'],
#  '568': ['n02966193',
#   'carousel, carrousel, merry-go-round, roundabout, whirligig'],
#  '569': ['n04371774', 'swing'],
#  '570': ['n04067472', 'reel'],
#  '571': ['n04040759', 'radiator'],
#  '572': ['n04019541', 'puck, hockey puck'],
#  '573': ['n03492542', 'hard disc, hard disk, fixed disk'],
#  '574': ['n04355933', 'sunglass'],
#  '575': ['n03929660', 'pick, plectrum, plectron'],
#  '576': ['n02965783', 'car mirror'],
#  '577': ['n04258138', 'solar dish, solar collector, solar furnace'],
#  '578': ['n04074963', 'remote control, remote'],
#  '579': ['n03208938', 'disk brake, disc brake'],
#  '580': ['n02910353', 'buckle'],
#  '581': ['n03476684', 'hair slide'],
#  '582': ['n03627232', 'knot'],
#  '583': ['n03075370', 'combination lock'],
#  '584': ['n03874599', 'padlock'],
#  '585': ['n03804744', 'nail'],
#  '586': ['n04127249', 'safety pin'],
#  '587': ['n04153751', 'screw'],
#  '588': ['n03803284', 'muzzle'],
#  '589': ['n04162706', 'seat belt, seatbelt'],
#  '590': ['n04228054', 'ski'],
#  '591': ['n02948072', 'candle, taper, wax light'],
#  '592': ['n03590841', "jack-o'-lantern"],
#  '593': ['n04286575', 'spotlight, spot'],
#  '594': ['n04456115', 'torch'],
#  '595': ['n03814639', 'neck brace'],
#  '596': ['n03933933', 'pier'],
#  '597': ['n04485082', 'tripod'],
#  '598': ['n03733131', 'maypole'],
#  '599': ['n03794056', 'mousetrap'],
#  '600': ['n04275548', "spider web, spider's web"],
#  '601': ['n01768244', 'trilobite'],
#  '602': ['n01770081', 'harvestman, daddy longlegs, Phalangium opilio'],
#  '603': ['n01770393', 'scorpion'],
#  '604': ['n01773157', 'black and gold garden spider, Argiope aurantia'],
#  '605': ['n01773549', 'barn spider, Araneus cavaticus'],
#  '606': ['n01773797', 'garden spider, Aranea diademata'],
#  '607': ['n01774384', 'black widow, Latrodectus mactans'],
#  '608': ['n01774750', 'tarantula'],
#  '609': ['n01775062', 'wolf spider, hunting spider'],
#  '610': ['n01776313', 'tick'],
#  '611': ['n01784675', 'centipede'],
#  '612': ['n01990800', 'isopod'],
#  '613': ['n01978287', 'Dungeness crab, Cancer magister'],
#  '614': ['n01978455', 'rock crab, Cancer irroratus'],
#  '615': ['n01980166', 'fiddler crab'],
#  '616': ['n01981276',
#   'king crab, Alaska crab, Alaskan king crab, Alaska king crab, Paralithodes camtschatica'],
#  '617': ['n01983481',
#   'American lobster, Northern lobster, Maine lobster, Homarus americanus'],
#  '618': ['n01984695',
#   'spiny lobster, langouste, rock lobster, crawfish, crayfish, sea crawfish'],
#  '619': ['n01985128', 'crayfish, crawfish, crawdad, crawdaddy'],
#  '620': ['n01986214', 'hermit crab'],
#  '621': ['n02165105', 'tiger beetle'],
#  '622': ['n02165456',
#   'ladybug, ladybeetle, lady beetle, ladybird, ladybird beetle'],
#  '623': ['n02167151', 'ground beetle, carabid beetle'],
#  '624': ['n02168699', 'long-horned beetle, longicorn, longicorn beetle'],
#  '625': ['n02169497', 'leaf beetle, chrysomelid'],
#  '626': ['n02172182', 'dung beetle'],
#  '627': ['n02174001', 'rhinoceros beetle'],
#  '628': ['n02177972', 'weevil'],
#  '629': ['n02190166', 'fly'],
#  '630': ['n02206856', 'bee'],
#  '631': ['n02226429', 'grasshopper, hopper'],
#  '632': ['n02229544', 'cricket'],
#  '633': ['n02231487', 'walking stick, walkingstick, stick insect'],
#  '634': ['n02233338', 'cockroach, roach'],
#  '635': ['n02236044', 'mantis, mantid'],
#  '636': ['n02256656', 'cicada, cicala'],
#  '637': ['n02259212', 'leafhopper'],
#  '638': ['n02264363', 'lacewing, lacewing fly'],
#  '639': ['n02268443',
#   "dragonfly, darning needle, devil's darning needle, sewing needle, snake feeder, snake doctor, mosquito hawk, skeeter hawk"],
#  '640': ['n02268853', 'damselfly'],
#  '641': ['n02276258', 'admiral'],
#  '642': ['n02277742', 'ringlet, ringlet butterfly'],
#  '643': ['n02279972',
#   'monarch, monarch butterfly, milkweed butterfly, Danaus plexippus'],
#  '644': ['n02280649', 'cabbage butterfly'],
#  '645': ['n02281406', 'sulphur butterfly, sulfur butterfly'],
#  '646': ['n02281787', 'lycaenid, lycaenid butterfly'],
#  '647': ['n01910747', 'jellyfish'],
#  '648': ['n01914609', 'sea anemone, anemone'],
#  '649': ['n01917289', 'brain coral'],
#  '650': ['n01924916', 'flatworm, platyhelminth'],
#  '651': ['n01930112', 'nematode, nematode worm, roundworm'],
#  '652': ['n01943899', 'conch'],
#  '653': ['n01944390', 'snail'],
#  '654': ['n01945685', 'slug'],
#  '655': ['n01950731', 'sea slug, nudibranch'],
#  '656': ['n01955084',
#   'chiton, coat-of-mail shell, sea cradle, polyplacophore'],
#  '657': ['n02319095', 'sea urchin'],
#  '658': ['n02321529', 'sea cucumber, holothurian'],
#  '659': ['n03584829', 'iron, smoothing iron'],
#  '660': ['n03297495', 'espresso maker'],
#  '661': ['n03761084', 'microwave, microwave oven'],
#  '662': ['n03259280', 'Dutch oven'],
#  '663': ['n04111531', 'rotisserie'],
#  '664': ['n04442312', 'toaster'],
#  '665': ['n04542943', 'waffle iron'],
#  '666': ['n04517823', 'vacuum, vacuum cleaner'],
#  '667': ['n03207941', 'dishwasher, dish washer, dishwashing machine'],
#  '668': ['n04070727', 'refrigerator, icebox'],
#  '669': ['n04554684', 'washer, automatic washer, washing machine'],
#  '670': ['n03133878', 'Crock Pot'],
#  '671': ['n03400231', 'frying pan, frypan, skillet'],
#  '672': ['n04596742', 'wok'],
#  '673': ['n02939185', 'caldron, cauldron'],
#  '674': ['n03063689', 'coffeepot'],
#  '675': ['n04398044', 'teapot'],
#  '676': ['n04270147', 'spatula'],
#  '677': ['n02699494', 'altar'],
#  '678': ['n04486054', 'triumphal arch'],
#  '679': ['n03899768', 'patio, terrace'],
#  '680': ['n04311004', 'steel arch bridge'],
#  '681': ['n04366367', 'suspension bridge'],
#  '682': ['n04532670', 'viaduct'],
#  '683': ['n02793495', 'barn'],
#  '684': ['n03457902', 'greenhouse, nursery, glasshouse'],
#  '685': ['n03877845', 'palace'],
#  '686': ['n03781244', 'monastery'],
#  '687': ['n03661043', 'library'],
#  '688': ['n02727426', 'apiary, bee house'],
#  '689': ['n02859443', 'boathouse'],
#  '690': ['n03028079', 'church, church building'],
#  '691': ['n03788195', 'mosque'],
#  '692': ['n04346328', 'stupa, tope'],
#  '693': ['n03956157', 'planetarium'],
#  '694': ['n04081281', 'restaurant, eating house, eating place, eatery'],
#  '695': ['n03032252',
#   'cinema, movie theater, movie theatre, movie house, picture palace'],
#  '696': ['n03529860', 'home theater, home theatre'],
#  '697': ['n03697007', 'lumbermill, sawmill'],
#  '698': ['n03065424', 'coil, spiral, volute, whorl, helix'],
#  '699': ['n03837869', 'obelisk'],
#  '700': ['n04458633', 'totem pole'],
#  '701': ['n02980441', 'castle'],
#  '702': ['n04005630', 'prison, prison house'],
#  '703': ['n03461385', 'grocery store, grocery, food market, market'],
#  '704': ['n02776631', 'bakery, bakeshop, bakehouse'],
#  '705': ['n02791270', 'barbershop'],
#  '706': ['n02871525', 'bookshop, bookstore, bookstall'],
#  '707': ['n02927161', 'butcher shop, meat market'],
#  '708': ['n03089624', 'confectionery, confectionary, candy store'],
#  '709': ['n04200800', 'shoe shop, shoe-shop, shoe store'],
#  '710': ['n04443257', 'tobacco shop, tobacconist shop, tobacconist'],
#  '711': ['n04462240', 'toyshop'],
#  '712': ['n03388043', 'fountain'],
#  '713': ['n03042490', 'cliff dwelling'],
#  '714': ['n04613696', 'yurt'],
#  '715': ['n03216828', 'dock, dockage, docking facility'],
#  '716': ['n02892201', 'brass, memorial tablet, plaque'],
#  '717': ['n03743016', 'megalith, megalithic structure'],
#  '718': ['n02788148', 'bannister, banister, balustrade, balusters, handrail'],
#  '719': ['n02894605',
#   'breakwater, groin, groyne, mole, bulwark, seawall, jetty'],
#  '720': ['n03160309', 'dam, dike, dyke'],
#  '721': ['n03000134', 'chainlink fence'],
#  '722': ['n03930313', 'picket fence, paling'],
#  '723': ['n04604644',
#   'worm fence, snake fence, snake-rail fence, Virginia fence'],
#  '724': ['n04326547', 'stone wall'],
#  '725': ['n03459775', 'grille, radiator grille'],
#  '726': ['n04239074', 'sliding door'],
#  '727': ['n04501370', 'turnstile'],
#  '728': ['n03792972', 'mountain tent'],
#  '729': ['n04149813', 'scoreboard'],
#  '730': ['n03530642', 'honeycomb'],
#  '731': ['n03961711', 'plate rack'],
#  '732': ['n03903868', 'pedestal, plinth, footstall'],
#  '733': ['n02814860', 'beacon, lighthouse, beacon light, pharos'],
#  '734': ['n07711569', 'mashed potato'],
#  '735': ['n07720875', 'bell pepper'],
#  '736': ['n07714571', 'head cabbage'],
#  '737': ['n07714990', 'broccoli'],
#  '738': ['n07715103', 'cauliflower'],
#  '739': ['n07716358', 'zucchini, courgette'],
#  '740': ['n07716906', 'spaghetti squash'],
#  '741': ['n07717410', 'acorn squash'],
#  '742': ['n07717556', 'butternut squash'],
#  '743': ['n07718472', 'cucumber, cuke'],
#  '744': ['n07718747', 'artichoke, globe artichoke'],
#  '745': ['n07730033', 'cardoon'],
#  '746': ['n07734744', 'mushroom'],
#  '747': ['n04209239', 'shower curtain'],
#  '748': ['n03594734', 'jean, blue jean, denim'],
#  '749': ['n02971356', 'carton'],
#  '750': ['n03485794', 'handkerchief, hankie, hanky, hankey'],
#  '751': ['n04133789', 'sandal'],
#  '752': ['n02747177',
#   'ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin'],
#  '753': ['n04125021', 'safe'],
#  '754': ['n07579787', 'plate'],
#  '755': ['n03814906', 'necklace'],
#  '756': ['n03134739', 'croquet ball'],
#  '757': ['n03404251', 'fur coat'],
#  '758': ['n04423845', 'thimble'],
#  '759': ['n03877472', "pajama, pyjama, pj's, jammies"],
#  '760': ['n04120489', 'running shoe'],
#  '761': ['n03062245', 'cocktail shaker'],
#  '762': ['n03014705', 'chest'],
#  '763': ['n03717622', 'manhole cover'],
#  '764': ['n03777754', 'modem'],
#  '765': ['n04493381', 'tub, vat'],
#  '766': ['n04476259', 'tray'],
#  '767': ['n02777292', 'balance beam, beam'],
#  '768': ['n07693725', 'bagel, beigel'],
#  '769': ['n03998194', 'prayer rug, prayer mat'],
#  '770': ['n03617480', 'kimono'],
#  '771': ['n07590611', 'hot pot, hotpot'],
#  '772': ['n04579145', 'whiskey jug'],
#  '773': ['n03623198', 'knee pad'],
#  '774': ['n07248320', 'book jacket, dust cover, dust jacket, dust wrapper'],
#  '775': ['n04277352', 'spindle'],
#  '776': ['n04229816', 'ski mask'],
#  '777': ['n02823428', 'beer bottle'],
#  '778': ['n03127747', 'crash helmet'],
#  '779': ['n02877765', 'bottlecap'],
#  '780': ['n04435653', 'tile roof'],
#  '781': ['n03724870', 'mask'],
#  '782': ['n03710637', 'maillot'],
#  '783': ['n03920288', 'Petri dish'],
#  '784': ['n03379051', 'football helmet'],
#  '785': ['n02807133', 'bathing cap, swimming cap'],
#  '786': ['n04399382', 'teddy, teddy bear'],
#  '787': ['n03527444', 'holster'],
#  '788': ['n03983396', 'pop bottle, soda bottle'],
#  '789': ['n03924679', 'photocopier'],
#  '790': ['n04532106', 'vestment'],
#  '791': ['n06785654', 'crossword puzzle, crossword'],
#  '792': ['n03445777', 'golf ball'],
#  '793': ['n07613480', 'trifle'],
#  '794': ['n04350905', 'suit, suit of clothes'],
#  '795': ['n04562935', 'water tower'],
#  '796': ['n03325584', 'feather boa, boa'],
#  '797': ['n03045698', 'cloak'],
#  '798': ['n07892512', 'red wine'],
#  '799': ['n03250847', 'drumstick'],
#  '800': ['n04192698', 'shield, buckler'],
#  '801': ['n03026506', 'Christmas stocking'],
#  '802': ['n03534580', 'hoopskirt, crinoline'],
#  '803': ['n07565083', 'menu'],
#  '804': ['n04296562', 'stage'],
#  '805': ['n02869837', 'bonnet, poke bonnet'],
#  '806': ['n07871810', 'meat loaf, meatloaf'],
#  '807': ['n02799071', 'baseball'],
#  '808': ['n03314780', 'face powder'],
#  '809': ['n04141327', 'scabbard'],
#  '810': ['n04357314', 'sunscreen, sunblock, sun blocker'],
#  '811': ['n02823750', 'beer glass'],
#  '812': ['n13052670',
#   'hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa'],
#  '813': ['n07583066', 'guacamole'],
#  '814': ['n03637318', 'lampshade, lamp shade'],
#  '815': ['n04599235', 'wool, woolen, woollen'],
#  '816': ['n07802026', 'hay'],
#  '817': ['n02883205', 'bow tie, bow-tie, bowtie'],
#  '818': ['n03709823', 'mailbag, postbag'],
#  '819': ['n04560804', 'water jug'],
#  '820': ['n02909870', 'bucket, pail'],
#  '821': ['n03207743', 'dishrag, dishcloth'],
#  '822': ['n04263257', 'soup bowl'],
#  '823': ['n07932039', 'eggnog'],
#  '824': ['n03786901', 'mortar'],
#  '825': ['n04479046', 'trench coat'],
#  '826': ['n03873416', 'paddle, boat paddle'],
#  '827': ['n02999410', 'chain'],
#  '828': ['n04367480', 'swab, swob, mop'],
#  '829': ['n03775546', 'mixing bowl'],
#  '830': ['n07875152', 'potpie'],
#  '831': ['n04591713', 'wine bottle'],
#  '832': ['n04201297', 'shoji'],
#  '833': ['n02916936', 'bulletproof vest'],
#  '834': ['n03240683', 'drilling platform, offshore rig'],
#  '835': ['n02840245', 'binder, ring-binder'],
#  '836': ['n02963159', 'cardigan'],
#  '837': ['n04370456', 'sweatshirt'],
#  '838': ['n03991062', 'pot, flowerpot'],
#  '839': ['n02843684', 'birdhouse'],
#  '840': ['n03482405', 'hamper'],
#  '841': ['n03942813', 'ping-pong ball'],
#  '842': ['n03908618', 'pencil box, pencil case'],
#  '843': ['n03902125', 'pay-phone, pay-station'],
#  '844': ['n07584110', 'consomme'],
#  '845': ['n02730930', 'apron'],
#  '846': ['n04023962', 'punching bag, punch bag, punching ball, punchball'],
#  '847': ['n02769748',
#   'backpack, back pack, knapsack, packsack, rucksack, haversack'],
#  '848': ['n10148035', 'groom, bridegroom'],
#  '849': ['n02817516', 'bearskin, busby, shako'],
#  '850': ['n03908714', 'pencil sharpener'],
#  '851': ['n02906734', 'broom'],
#  '852': ['n03788365', 'mosquito net'],
#  '853': ['n02667093', 'abaya'],
#  '854': ['n03787032', 'mortarboard'],
#  '855': ['n03980874', 'poncho'],
#  '856': ['n03141823', 'crutch'],
#  '857': ['n03976467', 'Polaroid camera, Polaroid Land camera'],
#  '858': ['n04264628', 'space bar'],
#  '859': ['n07930864', 'cup'],
#  '860': ['n04039381', 'racket, racquet'],
#  '861': ['n06874185', 'traffic light, traffic signal, stoplight'],
#  '862': ['n04033901', 'quill, quill pen'],
#  '863': ['n04041544', 'radio, wireless'],
#  '864': ['n07860988', 'dough'],
#  '865': ['n03146219', 'cuirass'],
#  '866': ['n03763968', 'military uniform'],
#  '867': ['n03676483', 'lipstick, lip rouge'],
#  '868': ['n04209133', 'shower cap'],
#  '869': ['n03782006', 'monitor'],
#  '870': ['n03857828', 'oscilloscope, scope, cathode-ray oscilloscope, CRO'],
#  '871': ['n03775071', 'mitten'],
#  '872': ['n02892767', 'brassiere, bra, bandeau'],
#  '873': ['n07684084', 'French loaf'],
#  '874': ['n04522168', 'vase'],
#  '875': ['n03764736', 'milk can'],
#  '876': ['n04118538', 'rugby ball'],
#  '877': ['n03887697', 'paper towel'],
#  '878': ['n13044778', 'earthstar'],
#  '879': ['n03291819', 'envelope'],
#  '880': ['n03770439', 'miniskirt, mini'],
#  '881': ['n03124170', 'cowboy hat, ten-gallon hat'],
#  '882': ['n04487081', 'trolleybus, trolley coach, trackless trolley'],
#  '883': ['n03916031', 'perfume, essence'],
#  '884': ['n02808440', 'bathtub, bathing tub, bath, tub'],
#  '885': ['n07697537', 'hotdog, hot dog, red hot'],
#  '886': ['n12985857', 'coral fungus'],
#  '887': ['n02917067', 'bullet train, bullet'],
#  '888': ['n03938244', 'pillow'],
#  '889': ['n15075141', 'toilet tissue, toilet paper, bathroom tissue'],
#  '890': ['n02978881', 'cassette'],
#  '891': ['n02966687', "carpenter's kit, tool kit"],
#  '892': ['n03633091', 'ladle'],
#  '893': ['n13040303', 'stinkhorn, carrion fungus'],
#  '894': ['n03690938', 'lotion'],
#  '895': ['n03476991', 'hair spray'],
#  '896': ['n02669723', "academic gown, academic robe, judge's robe"],
#  '897': ['n03220513', 'dome'],
#  '898': ['n03127925', 'crate'],
#  '899': ['n04584207', 'wig'],
#  '900': ['n07880968', 'burrito'],
#  '901': ['n03937543', 'pill bottle'],
#  '902': ['n03000247',
#   'chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour'],
#  '903': ['n04418357', 'theater curtain, theatre curtain'],
#  '904': ['n04590129', 'window shade'],
#  '905': ['n02795169', 'barrel, cask'],
#  '906': ['n04553703',
#   'washbasin, handbasin, washbowl, lavabo, wash-hand basin'],
#  '907': ['n02783161', 'ballpoint, ballpoint pen, ballpen, Biro'],
#  '908': ['n02802426', 'basketball'],
#  '909': ['n02808304', 'bath towel'],
#  '910': ['n03124043', 'cowboy boot'],
#  '911': ['n03450230', 'gown'],
#  '912': ['n04589890', 'window screen'],
#  '913': ['n12998815', 'agaric'],
#  '914': ['n02992529',
#   'cellular telephone, cellular phone, cellphone, cell, mobile phone'],
#  '915': ['n03825788', 'nipple'],
#  '916': ['n02790996', 'barbell'],
#  '917': ['n03710193', 'mailbox, letter box'],
#  '918': ['n03630383', 'lab coat, laboratory coat'],
#  '919': ['n03347037', 'fire screen, fireguard'],
#  '920': ['n03769881', 'minibus'],
#  '921': ['n03871628', 'packet'],
#  '922': ['n03733281', 'maze, labyrinth'],
#  '923': ['n03976657', 'pole'],
#  '924': ['n03535780', 'horizontal bar, high bar'],
#  '925': ['n04259630', 'sombrero'],
#  '926': ['n03929855', 'pickelhaube'],
#  '927': ['n04049303', 'rain barrel'],
#  '928': ['n04548362', 'wallet, billfold, notecase, pocketbook'],
#  '929': ['n02979186', 'cassette player'],
#  '930': ['n06596364', 'comic book'],
#  '931': ['n03935335', 'piggy bank, penny bank'],
#  '932': ['n06794110', 'street sign'],
#  '933': ['n02825657', 'bell cote, bell cot'],
#  '934': ['n03388183', 'fountain pen'],
#  '935': ['n04591157', 'Windsor tie'],
#  '936': ['n04540053', 'volleyball'],
#  '937': ['n03866082', 'overskirt'],
#  '938': ['n04136333', 'sarong'],
#  '939': ['n04026417', 'purse'],
#  '940': ['n02865351', 'bolo tie, bolo, bola tie, bola'],
#  '941': ['n02834397', 'bib'],
#  '942': ['n03888257', 'parachute, chute'],
#  '943': ['n04235860', 'sleeping bag'],
#  '944': ['n04404412', 'television, television system'],
#  '945': ['n04371430', 'swimming trunks, bathing trunks'],
#  '946': ['n03733805', 'measuring cup'],
#  '947': ['n07920052', 'espresso'],
#  '948': ['n07873807', 'pizza, pizza pie'],
#  '949': ['n02895154', 'breastplate, aegis, egis'],
#  '950': ['n04204238', 'shopping basket'],
#  '951': ['n04597913', 'wooden spoon'],
#  '952': ['n04131690', 'saltshaker, salt shaker'],
#  '953': ['n07836838', 'chocolate sauce, chocolate syrup'],
#  '954': ['n09835506', 'ballplayer, baseball player'],
#  '955': ['n03443371', 'goblet'],
#  '956': ['n13037406', 'gyromitra'],
#  '957': ['n04336792', 'stretcher'],
#  '958': ['n04557648', 'water bottle'],
#  '959': ['n03187595', 'dial telephone, dial phone'],
#  '960': ['n04254120', 'soap dispenser'],
#  '961': ['n03595614', 'jersey, T-shirt, tee shirt'],
#  '962': ['n04146614', 'school bus'],
#  '963': ['n03598930', 'jigsaw puzzle'],
#  '964': ['n03958227', 'plastic bag'],
#  '965': ['n04069434', 'reflex camera'],
#  '966': ['n03188531', 'diaper, nappy, napkin'],
#  '967': ['n02786058', 'Band Aid'],
#  '968': ['n07615774', 'ice lolly, lolly, lollipop, popsicle'],
#  '969': ['n04525038', 'velvet'],
#  '970': ['n04409515', 'tennis ball'],
#  '971': ['n03424325', 'gasmask, respirator, gas helmet'],
#  '972': ['n03223299', 'doormat, welcome mat'],
#  '973': ['n03680355', 'Loafer'],
#  '974': ['n07614500', 'ice cream, icecream'],
#  '975': ['n07695742', 'pretzel'],
#  '976': ['n04033995', 'quilt, comforter, comfort, puff'],
#  '977': ['n03710721', 'maillot, tank suit'],
#  '978': ['n04392985', 'tape player'],
#  '979': ['n03047690', 'clog, geta, patten, sabot'],
#  '980': ['n03584254', 'iPod'],
#  '981': ['n13054560', 'bolete'],
#  '982': ['n10565667', 'scuba diver'],
#  '983': ['n03950228', 'pitcher, ewer'],
#  '984': ['n03729826', 'matchstick'],
#  '985': ['n02837789', 'bikini, two-piece'],
#  '986': ['n04254777', 'sock'],
#  '987': ['n02988304', 'CD player'],
#  '988': ['n03657121', 'lens cap, lens cover'],
#  '989': ['n04417672', 'thatch, thatched roof'],
#  '990': ['n04523525', 'vault'],
#  '991': ['n02815834', 'beaker'],
#  '992': ['n09229709', 'bubble'],
#  '993': ['n07697313', 'cheeseburger'],
#  '994': ['n03888605', 'parallel bars, bars'],
#  '995': ['n03355925', 'flagpole, flagstaff'],
#  '996': ['n03063599', 'coffee mug'],
#  '997': ['n04116512', 'rubber eraser, rubber, pencil eraser'],
#  '998': ['n04325704', 'stole'],
#  '999': ['n07831146', 'carbonara'],
#  '1000': ['n03255030', 'dumbbell'],
#  ...}

# %%
# There are two ways to load an image.

# 1
# input an ImageNet ID, 1~1000, indicating which class to load, we'll randomly choice one img in the class
img, pix_id, imagenet_id = load_img_from_imagenet_sample_by_class(80, imagenet_labels=imagenet_id_label)
model_id = int(map_dict_imagenet2model[str(imagenet_id)])
print("Pic ID is "+str(pix_id))
print("imagenet ID is "+str(imagenet_id))
print("Model class ID is "+str(model_id))
img
# Out:
# There are 5 imgs, and 1 classes.
# load img imagenet_sample/imagenet_sample_5000/80_n02391049_3.JPEG
# ImageNet ID: 80
# WNID and class: ['n02391049', 'zebra']
# Pic ID is 3
# imagenet ID is 80
# Model class ID is 340
# <PIL.Image.Image image mode=RGB size=500x372 at 0x7FCFB866C340>

# %%
# 2
# input an index indicating which image file to load
img2, pix_id2, imagenet_id2 = load_img_from_imagenet_sample_by_index(0, imagenet_labels=imagenet_id_label)
model_id2 = int(map_dict_imagenet2model[str(imagenet_id2)])
print("Pic ID is "+str(pix_id2))
print("imagenet ID is "+str(imagenet_id2))
print("Model class ID is "+str(model_id2))
img2
# Out:
# There are 5 imgs, and 1 classes.
# load img imagenet_sample/imagenet_sample_5000/80_n02391049_0.JPEG
# ImageNet ID: 80
# WNID and class: ['n02391049', 'zebra']
# Pic ID is 0
# imagenet ID is 80
# Model class ID is 340
# <PIL.Image.Image image mode=RGB size=352x500 at 0x7FCFB86E1A00>

# %% [markdown]
# ### function for image preprocessing

# %%
# process an ImageNet raw image to input it into a CNN
def preprocess_image(pil_im, resize_im=True):
    """
        Processes image for CNNs

    Args:
        PIL_img (PIL_img): PIL Image or numpy array to process
        resize_im (bool): Resize to 224 or not
    returns:
        im_as_var (torch variable): Variable that contains processed float tensor
    """
    # mean and std list for channels (Imagenet)
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]

    #ensure or transform incoming image to PIL image
    if type(pil_im) != Image.Image:
        try:
            pil_im = Image.fromarray(pil_im)
        except Exception as e:
            print("could not transform PIL_img to a PIL Image object. Please check input.")
            
    # Resize image
    if resize_im:
        pil_im = pil_im.resize((224, 224), Image.ANTIALIAS)
        
    im_as_arr = np.float32(pil_im)
    
    im_resize = np.array(im_as_arr, dtype = np.int)
    
    im_as_arr = im_as_arr.transpose(2, 0, 1)  # Convert array to D,W,H
    
    # Normalize the channels
    for channel, _ in enumerate(im_as_arr):
        im_as_arr[channel] /= 255
        im_as_arr[channel] -= mean[channel]
        im_as_arr[channel] /= std[channel]
    
    # Convert to float tensor
    im_as_ten = torch.from_numpy(im_as_arr).float()
    
    # Add one more channel to the beginning. Tensor shape = 1,3,224,224
    im_as_ten.unsqueeze_(0)
    
    # Convert to Pytorch variable
    im_as_var = Variable(im_as_ten, requires_grad=True)
    
    return im_as_var, im_resize

# %% [markdown]
# ### load pretrained model

# %%
pretrained_model = models.vgg19(pretrained=True)

print("model arch:")
print(pretrained_model)
#print(list(pretrained_model._modules.items()))
# Out:
# model arch:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ### hook activation and gradient of a certain layer

# %%
activation = []
gradient = []
def forward_hook(model, ten_in, ten_out):
    global activation
    activation.append(copy.deepcopy(ten_out.cpu().detach().numpy()))

def backward_hook(model, grad_in, grad_out):
    global gradient
    gradient.append(copy.deepcopy(grad_out[0].cpu().detach().numpy()))

# which layer to hook
N = 35

hook_layer = list(pretrained_model.named_modules())[N][1]
hook_layer.register_forward_hook(forward_hook)
hook_layer.register_backward_hook(backward_hook)

# %%
def get_layer_activation_gradient_of_an_image(img, modeloutput_id_label=None, model_id=None, get_gradient=False):
    global activation
    global gradient
    activation = []
    gradient = []
    input_img_tensor, _ = preprocess_image(img)
    if get_gradient:
        model_output=pretrained_model(input_img_tensor)
    else:
        with torch.no_grad():
            model_output=pretrained_model(input_img_tensor)
    
    predicted_model_id = torch.argmax(model_output).detach().cpu().numpy()
    print("predicted model id is "+str(predicted_model_id))
    
    if modeloutput_id_label is not None:
        print("predicted class is "+str(modeloutput_id_label[str(predicted_model_id)]))
    
    if model_id is not None and modeloutput_id_label is not None:
        print("true model id is "+str(model_id))
        print("true imagenet id is "+str(map_dict_model2imagenet[str(model_id)]))
        print("true class is "+str(modeloutput_id_label[str(model_id)]))
    
    if get_gradient:
        if model_id is not None and modeloutput_id_label is not None:
            pretrained_model.zero_grad()
            one_hot_output = torch.FloatTensor(1, model_output.size()[-1]).zero_()
            one_hot_output[0][model_id] = 1
            model_output.backward(gradient=one_hot_output)
        else:
            pretrained_model.zero_grad()
            one_hot_output = torch.FloatTensor(1, model_output.size()[-1]).zero_()
            one_hot_output[0][predicted_model_id] = 1
            model_output.backward(gradient=one_hot_output)

# %%
# note that here we use img2
get_layer_activation_gradient_of_an_image(img2, modeloutput_id_label, model_id2, get_gradient=True)

# you can also use the following script instead of get_layer_activation_gradient_of_an_image
# to hook activation map and gradient of a layer
'''
activation = []
gradient = []
input_img_tensor, input_img_arr = preprocess_image(img)
model_output=pretrained_model(input_img_tensor)

predicted_model_id = torch.argmax(model_output).detach().cpu().numpy()
print("predicted model id is "+str(predicted_model_id))
print("predicted class is "+str(modeloutput_id_label[str(predicted_model_id)]))
    
print("true model id is "+str(model_id))
print("true imagenet id is "+str(map_dict_model2imagenet[str(model_id)]))
print("true class is "+str(modeloutput_id_label[str(model_id)]))

pretrained_model.zero_grad()
one_hot_output = torch.FloatTensor(1, model_output.size()[-1]).zero_()
one_hot_output[0][model_id] = 1
model_output.backward(gradient=one_hot_output)
'''
# Out:
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# true model id is 340
# true imagenet id is 80
# true class is ['n02391049', 'zebra']
# '\nactivation = []\ngradient = []\ninput_img_tensor, input_img_arr = preprocess_image(img)\nmodel_output=pretrained_model(input_img_tensor)\n\npredicted_model_id = torch.argmax(model_output).detach().cpu().numpy()\nprint("predicted model id is "+str(predicted_model_id))\nprint("predicted class is "+str(modeloutput_id_label[str(predicted_model_id)]))\n    \nprint("true model id is "+str(model_id))\nprint("true imagenet id is "+str(map_dict_model2imagenet[str(model_id)]))\nprint("true class is "+str(modeloutput_id_label[str(model_id)]))\n\npretrained_model.zero_grad()\none_hot_output = torch.FloatTensor(1, model_output.size()[-1]).zero_()\none_hot_output[0][model_id] = 1\nmodel_output.backward(gradient=one_hot_output)\n'

# %%
activation_squeezed = np.squeeze(activation[0])
gradient_squeezed = np.squeeze(gradient[0])
print('activation shape: ', activation[0].shape)
print('gradient shape: ', gradient[0].shape)
print('Flat activation size: ', activation_squeezed.flatten().shape[0])
print('Flat gradient size: ', gradient_squeezed.flatten().shape[0])
# Out:
# activation shape:  (1, 512, 14, 14)
# gradient shape:  (1, 512, 14, 14)
# Flat activation size:  100352
# Flat gradient size:  100352

# %% [markdown]
# ### get cav (here we try the concept of 'striped')
# #### Please down load the texture dataset: https://www.robots.ox.ac.uk/~vgg/data/dtd/index.html

# %%
# the name of the texture dataset is dtd
texture_data_path = 'dtd/images/'

patterns = os.listdir(texture_data_path)

tgt_patterns = ['striped'] # concept(s) we care
rnd_patterns = patterns # concepts expect the one(s) we care
for patt in tgt_patterns:
    if patt in rnd_patterns:
        rnd_patterns.remove(patt)

# %%
### concept set
concept_act_s = []
concept_lbl_s = []

for patt in tgt_patterns:
    for concept_files in os.listdir(texture_data_path.format(patt)+patt):
        
        concept_img_path = texture_data_path.format(patt)+patt+'/'+concept_files
        print(concept_img_path)
        
        concept_img = Image.open(concept_img_path).convert('RGB')
        get_layer_activation_gradient_of_an_image(concept_img, modeloutput_id_label)
        print('--------------------------------------------------')
        concept_act_s.append(np.squeeze(activation[0]).flatten())
        concept_lbl_s.append(0)
# Out:
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0105.jpg
# predicted model id is 326
# predicted class is ['n02281787', 'lycaenid']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0063.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0011.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0087.jpg
# predicted model id is 852
# predicted class is ['n04409515', 'tennis_ball']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0021.jpg
# predicted model id is 721
# predicted class is ['n03938244', 'pillow']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0119.jpg
# predicted model id is 774
# predicted class is ['n04133789', 'sandal']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0067.jpg
# predicted model id is 636
# predicted class is ['n03709823', 'mailbag']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0122.jpg
# predicted model id is 397
# predicted class is ['n02655020', 'puffer']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0065.jpg
# predicted model id is 568
# predicted class is ['n03404251', 'fur_coat']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0055.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0113.jpg
# predicted model id is 464
# predicted class is ['n02910353', 'buckle']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0096.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0106.jpg
# predicted model id is 770
# predicted class is ['n04120489', 'running_shoe']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0066.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0084.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0060.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0003.jpg
# predicted model id is 392
# predicted class is ['n02606052', 'rock_beauty']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0093.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0094.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0002.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0107.jpg
# predicted model id is 721
# predicted class is ['n03938244', 'pillow']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0117.jpg
# predicted model id is 883
# predicted class is ['n04522168', 'vase']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0102.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0041.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0115.jpg
# predicted model id is 775
# predicted class is ['n04136333', 'sarong']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0095.jpg
# predicted model id is 396
# predicted class is ['n02643566', 'lionfish']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0074.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0077.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0027.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0114.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0038.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0004.jpg
# predicted model id is 392
# predicted class is ['n02606052', 'rock_beauty']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0008.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0032.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0015.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0056.jpg
# predicted model id is 824
# predicted class is ['n04325704', 'stole']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0049.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0020.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0079.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0040.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0103.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0042.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0086.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0112.jpg
# predicted model id is 996
# predicted class is ['n13052670', 'hen-of-the-woods']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0091.jpg
# predicted model id is 775
# predicted class is ['n04136333', 'sarong']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0034.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0124.jpg
# predicted model id is 911
# predicted class is ['n04599235', 'wool']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0062.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0013.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0053.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0116.jpg
# predicted model id is 494
# predicted class is ['n03017168', 'chime']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0070.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0044.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0028.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0110.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0068.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0089.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0046.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0017.jpg
# predicted model id is 646
# predicted class is ['n03733281', 'maze']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0043.jpg
# predicted model id is 775
# predicted class is ['n04136333', 'sarong']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0069.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0016.jpg
# predicted model id is 588
# predicted class is ['n03482405', 'hamper']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0100.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0037.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0026.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0039.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0072.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0057.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0111.jpg
# predicted model id is 854
# predicted class is ['n04418357', 'theater_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0029.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0051.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0001.jpg
# predicted model id is 506
# predicted class is ['n03065424', 'coil']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0108.jpg
# predicted model id is 799
# predicted class is ['n04239074', 'sliding_door']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0052.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0014.jpg
# predicted model id is 911
# predicted class is ['n04599235', 'wool']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0064.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0075.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0090.jpg
# predicted model id is 414
# predicted class is ['n02769748', 'backpack']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0035.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0058.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0076.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0019.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0050.jpg
# predicted model id is 770
# predicted class is ['n04120489', 'running_shoe']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0109.jpg
# predicted model id is 798
# predicted class is ['n04238763', 'slide_rule']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0101.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0033.jpg
# predicted model id is 552
# predicted class is ['n03325584', 'feather_boa']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0080.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0022.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0092.jpg
# predicted model id is 750
# predicted class is ['n04033995', 'quilt']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0125.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0005.jpg
# predicted model id is 906
# predicted class is ['n04591157', 'Windsor_tie']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0023.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0030.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0104.jpg
# predicted model id is 533
# predicted class is ['n03207743', 'dishrag']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0078.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0120.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0054.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0006.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0071.jpg
# predicted model id is 775
# predicted class is ['n04136333', 'sarong']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0085.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0031.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0061.jpg
# predicted model id is 646
# predicted class is ['n03733281', 'maze']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0025.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0088.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0123.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0073.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0098.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0047.jpg
# predicted model id is 290
# predicted class is ['n02128925', 'jaguar']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0099.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0012.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0045.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0083.jpg
# predicted model id is 885
# predicted class is ['n04525038', 'velvet']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0081.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0010.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0121.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0036.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0097.jpg
# predicted model id is 292
# predicted class is ['n02129604', 'tiger']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0024.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0082.jpg
# predicted model id is 340
# predicted class is ['n02391049', 'zebra']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/striped/striped_0118.jpg
# predicted model id is 842
# predicted class is ['n04371430', 'swimming_trunks']
# --------------------------------------------------

# %%
### random set

random_act_s = []
random_lbl_s = []


for i in range(len(concept_act_s)):

    patt = random.choice(rnd_patterns)
    rand_concept_img_path = texture_data_path.format(patt)+patt+'/'+random.choice(os.listdir(texture_data_path.format(patt)+patt))
    print(rand_concept_img_path)
    
    rand_concept_img = Image.open(rand_concept_img_path).convert('RGB')
    get_layer_activation_gradient_of_an_image(rand_concept_img, modeloutput_id_label)
    print('--------------------------------------------------')
    random_act_s.append(np.squeeze(activation[0]).flatten())
    random_lbl_s.append(1)
# Out:
# /home/users/wangad/Projects/data/dtd/images/grooved/grooved_0109.jpg
# predicted model id is 835
# predicted class is ['n04355338', 'sundial']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/chequered/chequered_0088.jpg
# predicted model id is 904
# predicted class is ['n04589890', 'window_screen']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/studded/studded_0166.jpg
# predicted model id is 828
# predicted class is ['n04332243', 'strainer']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/potholed/potholed_0040.jpg
# predicted model id is 500
# predicted class is ['n03042490', 'cliff_dwelling']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/blotchy/blotchy_0093.jpg
# predicted model id is 885
# predicted class is ['n04525038', 'velvet']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/pleated/pleated_0128.jpg
# predicted model id is 419
# predicted class is ['n02786058', 'Band_Aid']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/scaly/scaly_0135.jpg
# predicted model id is 911
# predicted class is ['n04599235', 'wool']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/braided/braided_0153.jpg
# predicted model id is 588
# predicted class is ['n03482405', 'hamper']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/grooved/grooved_0105.jpg
# predicted model id is 904
# predicted class is ['n04589890', 'window_screen']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/swirly/swirly_0084.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/grid/grid_0045.jpg
# predicted model id is 916
# predicted class is ['n06359193', 'web_site']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/lined/lined_0117.jpg
# predicted model id is 750
# predicted class is ['n04033995', 'quilt']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/veined/veined_0092.jpg
# predicted model id is 815
# predicted class is ['n04275548', 'spider_web']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/banded/banded_0102.jpg
# predicted model id is 911
# predicted class is ['n04599235', 'wool']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/bumpy/bumpy_0103.jpg
# predicted model id is 599
# predicted class is ['n03530642', 'honeycomb']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/sprinkled/sprinkled_0096.jpg
# predicted model id is 666
# predicted class is ['n03786901', 'mortar']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/studded/studded_0207.jpg
# predicted model id is 828
# predicted class is ['n04332243', 'strainer']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/studded/studded_0054.jpg
# predicted model id is 632
# predicted class is ['n03691459', 'loudspeaker']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/braided/braided_0067.jpg
# predicted model id is 533
# predicted class is ['n03207743', 'dishrag']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/porous/porous_0053.jpg
# predicted model id is 42
# predicted class is ['n01687978', 'agama']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/scaly/scaly_0182.jpg
# predicted model id is 796
# predicted class is ['n04229816', 'ski_mask']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/meshed/meshed_0103.jpg
# predicted model id is 828
# predicted class is ['n04332243', 'strainer']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/cobwebbed/cobwebbed_0061.jpg
# predicted model id is 815
# predicted class is ['n04275548', 'spider_web']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/swirly/swirly_0157.jpg
# predicted model id is 854
# predicted class is ['n04418357', 'theater_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/potholed/potholed_0062.jpg
# predicted model id is 734
# predicted class is ['n03977966', 'police_van']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/blotchy/blotchy_0073.jpg
# predicted model id is 500
# predicted class is ['n03042490', 'cliff_dwelling']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/sprinkled/sprinkled_0065.jpg
# predicted model id is 769
# predicted class is ['n04118776', 'rule']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/spiralled/spiralled_0077.jpg
# predicted model id is 111
# predicted class is ['n01930112', 'nematode']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/swirly/swirly_0129.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/porous/porous_0141.jpg
# predicted model id is 930
# predicted class is ['n07684084', 'French_loaf']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/bumpy/bumpy_0134.jpg
# predicted model id is 33
# predicted class is ['n01664065', 'loggerhead']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/porous/porous_0150.jpg
# predicted model id is 954
# predicted class is ['n07753592', 'banana']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/zigzagged/zigzagged_0082.jpg
# predicted model id is 646
# predicted class is ['n03733281', 'maze']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/freckled/freckled_0120.jpg
# predicted model id is 643
# predicted class is ['n03724870', 'mask']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/potholed/potholed_0107.jpg
# predicted model id is 980
# predicted class is ['n09472597', 'volcano']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/banded/banded_0081.jpg
# predicted model id is 916
# predicted class is ['n06359193', 'web_site']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/cracked/cracked_0129.jpg
# predicted model id is 640
# predicted class is ['n03717622', 'manhole_cover']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/knitted/knitted_0156.jpg
# predicted model id is 533
# predicted class is ['n03207743', 'dishrag']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/meshed/meshed_0112.jpg
# predicted model id is 904
# predicted class is ['n04589890', 'window_screen']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/banded/banded_0030.jpg
# predicted model id is 885
# predicted class is ['n04525038', 'velvet']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/smeared/smeared_0060.jpg
# predicted model id is 112
# predicted class is ['n01943899', 'conch']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/pleated/pleated_0115.jpg
# predicted model id is 506
# predicted class is ['n03065424', 'coil']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/veined/veined_0093.jpg
# predicted model id is 825
# predicted class is ['n04326547', 'stone_wall']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/veined/veined_0172.jpg
# predicted model id is 317
# predicted class is ['n02259212', 'leafhopper']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/studded/studded_0134.jpg
# predicted model id is 822
# predicted class is ['n04311174', 'steel_drum']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/wrinkled/wrinkled_0077.jpg
# predicted model id is 689
# predicted class is ['n03866082', 'overskirt']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/wrinkled/wrinkled_0109.jpg
# predicted model id is 700
# predicted class is ['n03887697', 'paper_towel']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/pitted/pitted_0124.jpg
# predicted model id is 310
# predicted class is ['n02219486', 'ant']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/braided/braided_0074.jpg
# predicted model id is 506
# predicted class is ['n03065424', 'coil']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/zigzagged/zigzagged_0069.jpg
# predicted model id is 549
# predicted class is ['n03291819', 'envelope']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/flecked/flecked_0148.jpg
# predicted model id is 474
# predicted class is ['n02963159', 'cardigan']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/lined/lined_0095.jpg
# predicted model id is 905
# predicted class is ['n04590129', 'window_shade']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/interlaced/interlaced_0175.jpg
# predicted model id is 464
# predicted class is ['n02910353', 'buckle']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/woven/woven_0050.jpg
# predicted model id is 858
# predicted class is ['n04435653', 'tile_roof']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/dotted/dotted_0134.jpg
# predicted model id is 893
# predicted class is ['n04548362', 'wallet']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/pitted/pitted_0105.jpg
# predicted model id is 310
# predicted class is ['n02219486', 'ant']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/fibrous/fibrous_0174.jpg
# predicted model id is 272
# predicted class is ['n02114855', 'coyote']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/frilly/frilly_0092.jpg
# predicted model id is 937
# predicted class is ['n07714990', 'broccoli']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/zigzagged/zigzagged_0009.jpg
# predicted model id is 750
# predicted class is ['n04033995', 'quilt']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/fibrous/fibrous_0125.jpg
# predicted model id is 41
# predicted class is ['n01685808', 'whiptail']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/porous/porous_0158.jpg
# predicted model id is 930
# predicted class is ['n07684084', 'French_loaf']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/smeared/smeared_0097.jpg
# predicted model id is 972
# predicted class is ['n09246464', 'cliff']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/perforated/perforated_0038.jpg
# predicted model id is 754
# predicted class is ['n04041544', 'radio']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/zigzagged/zigzagged_0129.jpg
# predicted model id is 750
# predicted class is ['n04033995', 'quilt']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/crosshatched/crosshatched_0149.jpg
# predicted model id is 591
# predicted class is ['n03485794', 'handkerchief']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/meshed/meshed_0125.jpg
# predicted model id is 650
# predicted class is ['n03759954', 'microphone']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/potholed/potholed_0069.jpg
# predicted model id is 500
# predicted class is ['n03042490', 'cliff_dwelling']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/scaly/scaly_0184.jpg
# predicted model id is 608
# predicted class is ['n03594734', 'jean']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/fibrous/fibrous_0199.jpg
# predicted model id is 108
# predicted class is ['n01914609', 'sea_anemone']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/chequered/chequered_0123.jpg
# predicted model id is 918
# predicted class is ['n06785654', 'crossword_puzzle']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/bumpy/bumpy_0117.jpg
# predicted model id is 649
# predicted class is ['n03743016', 'megalith']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/frilly/frilly_0054.jpg
# predicted model id is 854
# predicted class is ['n04418357', 'theater_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/potholed/potholed_0135.jpg
# predicted model id is 313
# predicted class is ['n02231487', 'walking_stick']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/banded/banded_0033.jpg
# predicted model id is 446
# predicted class is ['n02840245', 'binder']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/braided/braided_0148.jpg
# predicted model id is 588
# predicted class is ['n03482405', 'hamper']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/studded/studded_0153.jpg
# predicted model id is 772
# predicted class is ['n04127249', 'safety_pin']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/crystalline/crystalline_0164.jpg
# predicted model id is 943
# predicted class is ['n07718472', 'cucumber']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/meshed/meshed_0100.jpg
# predicted model id is 489
# predicted class is ['n03000134', 'chainlink_fence']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/banded/banded_0059.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/dotted/dotted_0139.jpg
# predicted model id is 455
# predicted class is ['n02877765', 'bottlecap']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/marbled/marbled_0076.jpg
# predicted model id is 844
# predicted class is ['n04372370', 'switch']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/perforated/perforated_0130.jpg
# predicted model id is 753
# predicted class is ['n04040759', 'radiator']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/freckled/freckled_0108.jpg
# predicted model id is 903
# predicted class is ['n04584207', 'wig']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/cracked/cracked_0059.jpg
# predicted model id is 825
# predicted class is ['n04326547', 'stone_wall']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/swirly/swirly_0154.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/lacelike/lacelike_0001.jpg
# predicted model id is 824
# predicted class is ['n04325704', 'stole']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/blotchy/blotchy_0132.jpg
# predicted model id is 446
# predicted class is ['n02840245', 'binder']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/grid/grid_0124.jpg
# predicted model id is 640
# predicted class is ['n03717622', 'manhole_cover']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/wrinkled/wrinkled_0029.jpg
# predicted model id is 999
# predicted class is ['n15075141', 'toilet_tissue']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/porous/porous_0045.jpg
# predicted model id is 599
# predicted class is ['n03530642', 'honeycomb']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/waffled/waffled_0164.jpg
# predicted model id is 599
# predicted class is ['n03530642', 'honeycomb']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/banded/banded_0119.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/zigzagged/zigzagged_0021.jpg
# predicted model id is 538
# predicted class is ['n03220513', 'dome']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/matted/matted_0051.jpg
# predicted model id is 201
# predicted class is ['n02097658', 'silky_terrier']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/knitted/knitted_0156.jpg
# predicted model id is 474
# predicted class is ['n02963159', 'cardigan']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/waffled/waffled_0204.jpg
# predicted model id is 669
# predicted class is ['n03788365', 'mosquito_net']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/bubbly/bubbly_0096.jpg
# predicted model id is 971
# predicted class is ['n09229709', 'bubble']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/bubbly/bubbly_0130.jpg
# predicted model id is 700
# predicted class is ['n03887697', 'paper_towel']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/dotted/dotted_0182.jpg
# predicted model id is 893
# predicted class is ['n04548362', 'wallet']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/polka-dotted/polka-dotted_0032.jpg
# predicted model id is 549
# predicted class is ['n03291819', 'envelope']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/stratified/stratified_0106.jpg
# predicted model id is 525
# predicted class is ['n03160309', 'dam']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/swirly/swirly_0114.jpg
# predicted model id is 643
# predicted class is ['n03724870', 'mask']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/pitted/pitted_0095.jpg
# predicted model id is 853
# predicted class is ['n04417672', 'thatch']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/scaly/scaly_0137.jpg
# predicted model id is 533
# predicted class is ['n03207743', 'dishrag']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/studded/studded_0200.jpg
# predicted model id is 783
# predicted class is ['n04153751', 'screw']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/gauzy/gauzy_0137.jpg
# predicted model id is 753
# predicted class is ['n04040759', 'radiator']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/frilly/frilly_0018.jpg
# predicted model id is 990
# predicted class is ['n12768682', 'buckeye']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/scaly/scaly_0172.jpg
# predicted model id is 956
# predicted class is ['n07760859', 'custard_apple']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/bubbly/bubbly_0135.jpg
# predicted model id is 898
# predicted class is ['n04557648', 'water_bottle']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/paisley/paisley_0006.jpg
# predicted model id is 721
# predicted class is ['n03938244', 'pillow']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/lacelike/lacelike_0008.jpg
# predicted model id is 824
# predicted class is ['n04325704', 'stole']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/lacelike/lacelike_0035.jpg
# predicted model id is 721
# predicted class is ['n03938244', 'pillow']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/sprinkled/sprinkled_0135.jpg
# predicted model id is 611
# predicted class is ['n03598930', 'jigsaw_puzzle']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/sprinkled/sprinkled_0033.jpg
# predicted model id is 441
# predicted class is ['n02823750', 'beer_glass']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/woven/woven_0047.jpg
# predicted model id is 858
# predicted class is ['n04435653', 'tile_roof']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/zigzagged/zigzagged_0114.jpg
# predicted model id is 539
# predicted class is ['n03223299', 'doormat']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/sprinkled/sprinkled_0070.jpg
# predicted model id is 551
# predicted class is ['n03314780', 'face_powder']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/polka-dotted/polka-dotted_0126.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/pitted/pitted_0127.jpg
# predicted model id is 977
# predicted class is ['n09421951', 'sandbar']
# --------------------------------------------------
# /home/users/wangad/Projects/data/dtd/images/gauzy/gauzy_0166.jpg
# predicted model id is 794
# predicted class is ['n04209239', 'shower_curtain']
# --------------------------------------------------

# %%
def get_cav(concept_act_s,random_act_s,concept_lbl_s, random_lbl_s, clf_type = 'sgd'):

    X = np.vstack([concept_act_s,random_act_s])
    y = np.hstack([concept_lbl_s, random_lbl_s])
    X_tr, X_vl, y_tr, y_vl = train_test_split(X, y, shuffle= True)
    
    print('X train size: ',X_tr.shape)
    print('y train size: ',y_tr.shape)
    print('X valid size: ',X_vl.shape)
    print('y valid size: ',y_vl.shape)
    
    if clf_type == 'sgd':
        clf = linear_model.SGDClassifier(alpha=.01)
        
    elif clf_type == 'logistic':
        clf = linear_model.LogisticRegression()
        
    clf.fit(X_tr, y_tr)
    
    print('Training score: ',clf.score(X_tr, y_tr))
    print('Validation score: ',clf.score(X_vl, y_vl))

    cav = clf.coef_[0]
    
    return cav

# %%
cav = get_cav(concept_act_s,random_act_s,concept_lbl_s, random_lbl_s, clf_type='logistic')
print('cav shape: ', cav.shape)
# Out:
# X train size:  (180, 100352)
# y train size:  (180,)
# X valid size:  (60, 100352)
# y valid size:  (60,)
# Training score:  1.0
# Validation score:  0.9
# cav shape:  (100352,)

# %% [markdown]
# ### Test with CAV

# %%
directional_derivative = np.dot(np.reshape(gradient_squeezed.flatten(),-1),cav)

sign_dir_der = directional_derivative < 0

print("\"conceptual sensitivity\" of class k to concept C")
print("If directional_derivative<0, it means that class k is sensitive to concept C")
print(sign_dir_der, directional_derivative)
# Out:
# "conceptual sensitivity" of class k to concept C
# If directional_derivative<0, it means that class k is sensitive to concept C
# True -0.008123597920756264
